# %%
#Importaciones
from modelo_sign01 import create_model_sign01
from modelo_sign02 import create_model_sign02
from modelo_sign03 import create_model_sign03
from tensorflow.keras.utils import plot_model


models = list()

models.append(
    create_model_sign01(       
    )
)

models.append(
    create_model_sign02(       
    )
)

models.append(
    create_model_sign03(       
    )
)


i = 0
for model in models:
    i = i + 1
    name = 'modelo_sing0' + str(i)
    print("---------------", name,  "-----------------")
    print(model.summary())
    plot_model(model, to_file=name+".png", show_shapes=True)
# Out:
# --------------- modelo_sing01 -----------------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 98, 98, 96)        2688
#
#  max_pooling2d_5 (MaxPooling  (None, 49, 49, 96)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 47, 47, 128)       110720
#
#  max_pooling2d_6 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 21, 21, 160)       184480
#
#  conv2d_11 (Conv2D)          (None, 19, 19, 192)       276672
#
#  flatten_3 (Flatten)         (None, 69312)             0
#
#  dropout_5 (Dropout)         (None, 69312)             0
#
#  dense_7 (Dense)             (None, 10)                693130
#
# =================================================================
# Total params: 1,267,690
# Trainable params: 1,267,690
# Non-trainable params: 0
# _________________________________________________________________
# None
# --------------- modelo_sing02 -----------------
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 98, 98, 96)        2688
#
#  max_pooling2d_7 (MaxPooling  (None, 49, 49, 96)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 47, 47, 128)       110720
#
#  max_pooling2d_8 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 21, 21, 160)       184480
#
#  max_pooling2d_9 (MaxPooling  (None, 10, 10, 160)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 192)         276672
#
#  global_average_pooling2d_1   (None, 192)              0
#  (GlobalAveragePooling2D)
#
#  flatten_4 (Flatten)         (None, 192)               0
#
#  dense_8 (Dense)             (None, 2048)              395264
#
#  dropout_6 (Dropout)         (None, 2048)              0
#
#  dense_9 (Dense)             (None, 1024)              2098176
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 10)                10250
#
# =================================================================
# Total params: 3,078,250
# Trainable params: 3,078,250
# Non-trainable params: 0
# _________________________________________________________________
# None
# --------------- modelo_sing03 -----------------
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 4608)              0
#
#  dense_11 (Dense)            (None, 128)               589952
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 256)               33024
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 15,340,234
# Trainable params: 625,546
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
